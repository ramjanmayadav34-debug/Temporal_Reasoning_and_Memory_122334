# %% [markdown]
# # Temporal Reasoning Exploration
#
# This notebook explores the temporal reasoning model.

# %%
from src.model import TemporalReasoningModel
from src.utils import visualize_memory
import torch

# Initialize model
model = TemporalReasoningModel()

# Process a sequence
sequence = "The server started. A user logged in. The database crashed."
model.process_sequence(sequence)

# Query
query = "What happened to the database?"
output = model.answer_query(query)
print("Output:", output)

# Visualize
visualize_memory(model.memory)
